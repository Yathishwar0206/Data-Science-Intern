# %% [markdown]
# ### Project
# ## Project Name = **Fitness Dataset Analysis**.

# %% [markdown]
# ## Importing libraries
# 1. Import pandas as pd
# 2. Import matplotlib.pyplot as plt
# 3. Import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the Dataset

# %%
df = pd.read_csv(r'C:\Users\ADMIN\Desktop\Jupyter folder/Downloads/fitness_dataset_ml.csv')
df
# Out:
#        TotalSteps  Calories  SedentaryMinutes  LightlyActiveMinutes  \
# 0           13162      1985               728                   328
# 1           13162      1985               728                   328
# 2           13162      1985               728                   328
# 3           13162      1985               728                   328
# 4           13162      1985               728                   328
# ...           ...       ...               ...                   ...
# 12620        8064      1849               770                   137
# 12621        8064      1849               770                   137
# 12622        8064      1849               770                   137
# 12623        8064      1849               770                   137
# 12624        8064      1849               770                   137
#
#        FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                       13                 25                      0.0
# ...

# %% [markdown]
# ## Observation
# - The Above Dataset is Successfully loaded.

# %% [markdown]
# ## Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12625 entries, 0 to 12624
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TotalSteps                12625 non-null  int64
#  1   Calories                  12625 non-null  int64
#  2   SedentaryMinutes          12625 non-null  int64
#  3   LightlyActiveMinutes      12625 non-null  int64
#  4   FairlyActiveMinutes       12625 non-null  int64
#  5   VeryActiveMinutes         12625 non-null  int64
#  6   SedentaryActiveDistance   12625 non-null  float64
#  7   LightActiveDistance       12625 non-null  float64
#  8   ModeratelyActiveDistance  12625 non-null  float64
#  9   VeryActiveDistance        12625 non-null  float64
#  10  TotalActiveMinutes        12625 non-null  int64
#  11  TotalDistance             12625 non-null  float64
#  12  ActivityDayName           12625 non-null  object
# ...

# %% [markdown]
# ## Describing the Dataset

# %%
df.describe()
# Out:
#          TotalSteps      Calories  SedentaryMinutes  LightlyActiveMinutes  \
# count  12625.000000  12625.000000      12625.000000          12625.000000
# mean    7677.291564   2315.398495        992.791446            194.197545
# std     5106.688864    710.280611        298.075854            109.087189
# min        0.000000      0.000000          0.000000              0.000000
# 25%     3821.000000   1838.000000        730.000000            129.000000
# 50%     7412.000000   2150.000000       1057.000000            199.000000
# 75%    10735.000000   2796.000000       1229.000000            266.000000
# max    36019.000000   4900.000000       1440.000000            518.000000
#
#        FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# count         12625.000000       12625.000000             12625.000000
# mean             13.660436          21.265822                 0.001589
# std              20.030390          33.115259                 0.007336
# ...

# %% [markdown]
# ## Observation
# - The **Dataset** has **Described** is loaded successfully.

# %% [markdown]
# ## Display the first 10 rows of the dataset

# %%
df.head(10)
# Out:
#    TotalSteps  Calories  SedentaryMinutes  LightlyActiveMinutes  \
# 0       13162      1985               728                   328
# 1       13162      1985               728                   328
# 2       13162      1985               728                   328
# 3       13162      1985               728                   328
# 4       13162      1985               728                   328
# 5       13162      1985               728                   328
# 6       13162      1985               728                   328
# 7       13162      1985               728                   328
# 8       13162      1985               728                   328
# 9       13162      1985               728                   328
#
#    FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                   13                 25                      0.0
# 1                   13                 25                      0.0
# ...

# %% [markdown]
# ## Observation
# - The Above Dataset shows the First 10 rows of the dataset.

# %% [markdown]
# ## What is the shape of the dataset (rows, columns)?

# %%
print('The Rows and Columns of the Dataset : \n',df.shape)
# Out:
# The Rows and Columns of the Dataset :
#  (12625, 18)

# %% [markdown]
# ## Observation
# - Here, I shown the shape of the Dataset.
# - The **Row** is **12625** and **Column** is **18**.

# %% [markdown]
# ## Check for duplicate records. How many duplicates are present? Remove them.

# %%
print('Number of duplicates in the Dataset : ',df.duplicated().value_counts())
# Out:
# Number of duplicates in the Dataset :  False    12503
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Observation
# - There are **122** duplicate records in the Dataset.
# - Then, I drop the duplicate records from the dataset.

# %% [markdown]
# ## Check for null values in each column and handle them appropriately.

# %%
df.isnull().sum()
# Out:
# TotalSteps                  0
# Calories                    0
# SedentaryMinutes            0
# LightlyActiveMinutes        0
# FairlyActiveMinutes         0
# VeryActiveMinutes           0
# SedentaryActiveDistance     0
# LightActiveDistance         0
# ModeratelyActiveDistance    0
# VeryActiveDistance          0
# TotalActiveMinutes          0
# TotalDistance               0
# ActivityDayName             0
# TotalMinutesAsleep          0
# TotalTimeInBed              0
# WeightKg                    0
# Heightm                     0
# BMI                         0
# dtype: int64

# %% [markdown]
# ## Observation
# - There is no **Null** value in the Dataset.

# %% [markdown]
# ## Create new columns for: Total Distance, Total Minutes, and Total Active Minutes.

# %%
df = df.assign(TotalActiveMinutes = df.LightlyActiveMinutes+df.FairlyActiveMinutes+df.VeryActiveMinutes)

# %%
df
# Out:
#        TotalSteps  Calories  SedentaryMinutes  LightlyActiveMinutes  \
# 0           13162      1985               728                   328
# 1           13162      1985               728                   328
# 2           13162      1985               728                   328
# 3           13162      1985               728                   328
# 4           13162      1985               728                   328
# ...           ...       ...               ...                   ...
# 12620        8064      1849               770                   137
# 12621        8064      1849               770                   137
# 12622        8064      1849               770                   137
# 12623        8064      1849               770                   137
# 12624        8064      1849               770                   137
#
#        FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                       13                 25                      0.0
# ...

# %% [markdown]
# ## Observation
# - The Creation of New column **TotalActiveMinutes** is created successfully.

# %% [markdown]
# ## Drop unnecessary columns from the DataFrame

# %%
df.drop(columns=['LightlyActiveMinutes','FairlyActiveMinutes','VeryActiveMinutes','SedentaryActiveDistance',
        'LightActiveDistance','ModeratelyActiveDistance','VeryActiveDistance','BMI','TotalTimeInBed'],axis=1,inplace=True)

# %% [markdown]
# ## Observation
# - Now, I Dropped the all the Unwanted columns in the Dataset.

# %%
df.isnull().sum()
# Out:
# TotalSteps            0
# Calories              0
# SedentaryMinutes      0
# TotalActiveMinutes    0
# TotalDistance         0
# ActivityDayName       0
# TotalMinutesAsleep    0
# WeightKg              0
# Heightm               0
# dtype: int64

# %% [markdown]
# ## Rename columns in the DataFrame with meaningful names

# %%
df.rename(columns={'ActivityDayName':'Days','TotalSteps':'Steps','Calories':'Calories_burnt'},inplace=True)
df
# Out:
#        Steps  Calories_burnt  SedentaryMinutes  TotalActiveMinutes  \
# 0      13162            1985               728                 366
# 1      13162            1985               728                 366
# 2      13162            1985               728                 366
# 3      13162            1985               728                 366
# 4      13162            1985               728                 366
# ...      ...             ...               ...                 ...
# 12620   8064            1849               770                 161
# 12621   8064            1849               770                 161
# 12622   8064            1849               770                 161
# 12623   8064            1849               770                 161
# 12624   8064            1849               770                 161
#
#        TotalDistance      Days  TotalMinutesAsleep    WeightKg   Heightm
# 0               8.49   Tuesday                 327  119.653280  1.832444
# ...

# %% [markdown]
# ## Observation
# - The columns  name has changed for **TotalSteps as Steps, Calories as Calories_burnt, ActivityDayName as Days**.

# %% [markdown]
# ## Generate random values for an Age Group column.
# Import Numpy as np.

# %%
import numpy as np
df['AgeGroup'] = np.array(np.random.randint(17,55,(12503,1)))
df
# Out:
#        Steps  Calories_burnt  SedentaryMinutes  TotalActiveMinutes  \
# 0      13162            1985               728                 366
# 1      13162            1985               728                 366
# 2      13162            1985               728                 366
# 3      13162            1985               728                 366
# 4      13162            1985               728                 366
# ...      ...             ...               ...                 ...
# 12620   8064            1849               770                 161
# 12621   8064            1849               770                 161
# 12622   8064            1849               770                 161
# 12623   8064            1849               770                 161
# 12624   8064            1849               770                 161
#
#        TotalDistance      Days  TotalMinutesAsleep    WeightKg   Heightm  \
# 0               8.49   Tuesday                 327  119.653280  1.832444
# ...

# %% [markdown]
# ## Observation
# - In the Dataset, Added the New column **AgeGroup** and it generates Randomly.

# %% [markdown]
# ## Generate random values for a Gender column.

# %%
df['Gender'] = np.random.choice(['Male','Female'],size=len(df))
df
# Out:
#        Steps  Calories_burnt  SedentaryMinutes  TotalActiveMinutes  \
# 0      13162            1985               728                 366
# 1      13162            1985               728                 366
# 2      13162            1985               728                 366
# 3      13162            1985               728                 366
# 4      13162            1985               728                 366
# ...      ...             ...               ...                 ...
# 12620   8064            1849               770                 161
# 12621   8064            1849               770                 161
# 12622   8064            1849               770                 161
# 12623   8064            1849               770                 161
# 12624   8064            1849               770                 161
#
#        TotalDistance      Days  TotalMinutesAsleep    WeightKg   Heightm  \
# 0               8.49   Tuesday                 327  119.653280  1.832444
# ...

# %% [markdown]
# ## Observation
# - Now, Adding the New Column name **Gender** randomly.
# - It is successfully loaded and Added in the Dataset.

# %%
df.isnull().sum()
# Out:
# Steps                 0
# Calories_burnt        0
# SedentaryMinutes      0
# TotalActiveMinutes    0
# TotalDistance         0
# Days                  0
# TotalMinutesAsleep    0
# WeightKg              0
# Heightm               0
# AgeGroup              0
# Gender                0
# dtype: int64

# %% [markdown]
# ## Convert the categorical columns (e.g., Gender, Age Group) into categorical data types.

# %%
df['AgeGroup'] = df['AgeGroup'].astype('category')
df['Gender'] = df['Gender'].astype('category')

# %% [markdown]
# ## Observation
# - The Above dataset, I converted the **Gender,Agegroup** columns into Categorical datatype.

# %% [markdown]
# ## Perform outlier detection on numeric feature.

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
print(numeric_cols)
# Out:
# Index(['Steps', 'Calories_burnt', 'SedentaryMinutes', 'TotalActiveMinutes',
#        'TotalDistance', 'TotalMinutesAsleep', 'WeightKg', 'Heightm'],
#       dtype='object')

# %% [markdown]
# ## Remove outlier detection on numeric features

# %%
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    df = df[(df[col] >= Q1-1.5*IQR)&(df[col] <= Q3+1.5*IQR)]
df
# Out:
#        Steps  Calories_burnt  SedentaryMinutes  TotalActiveMinutes  \
# 0      13162            1985               728                 366
# 2      13162            1985               728                 366
# 3      13162            1985               728                 366
# 4      13162            1985               728                 366
# 5      13162            1985               728                 366
# ...      ...             ...               ...                 ...
# 12620   8064            1849               770                 161
# 12621   8064            1849               770                 161
# 12622   8064            1849               770                 161
# 12623   8064            1849               770                 161
# 12624   8064            1849               770                 161
#
#        TotalDistance      Days  TotalMinutesAsleep    WeightKg   Heightm  \
# 0               8.49   Tuesday                 327  119.653280  1.832444
# ...

# %% [markdown]
# ## Observation
# - Here, the Outliers are treated.

# %% [markdown]
# ## Extract Numeric features

# %%
numeric_features = df.select_dtypes(include=['number'])

# %% [markdown]
# ## Plot histogram of numeric features

# %%
for col in numeric_features:
    plt.figure(figsize=(8,5))

    sns.histplot(data=df, x=col, kde=True)
    plt.title(f" {col} Distribution")
    plt.show()
    print('---'*50)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Observation
# - The Above Dataset to Plot histogram of **Numeric Features**.
# - The all **Numeric features** were shown in each **Distribution**.

# %% [markdown]
# ## Visualize Total Active minutes by day of the week using a boxplot.

# %%
sns.boxplot(x='Days',y='TotalActiveMinutes',data=df)
plt.title('Total Active Minutes by Gender',fontweight='bold')
plt.show()

# %% [markdown]
# ## Observation
# - The Above Dataset, Visualizing the **Total Active Minutes by Day of the Week** using **Boxplot**.

# %% [markdown]
# ## Visualize Average Total Distance by Gender using a barplot.

# %%
sns.barplot(x='Gender',y='TotalDistance',data=df,estimator=np.mean)
plt.title('Average Total Distance by Gender',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observation
# - The Above dataset, **Average Total Distance by Gender** was successfully plotted using the **bar plot**.

# %% [markdown]
# ## Plot a pie chart showing the distribution of Gender.

# %%
plt.figure(figsize=(10,5))
df['Gender'].value_counts().plot(kind='pie',autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Gender',fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# ## Observation
# - The Above Dataset, **The Distribution of Gender** is successfully plotted using **Pie chart**.
# - It shows the balancing is **Equal**.

# %% [markdown]
# ## Count the number of entries for each Gender.

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    5618
# Male      5565
# Name: count, dtype: int64

# %% [markdown]
# ## Observation
# - The Above Dataset, **Counting the number of Entries for each Gender** is successfully Created.

# %% [markdown]
# ## Create a scatterplot of Total steps vs. calories burnt by gender.

# %%
sns.scatterplot(x='Steps',y='Calories_burnt',hue='Gender',data=df)
plt.show()

# %% [markdown]
# ## Observation
# - The Above dataset, Using the **Scatterplot** the **Total steps and calories by Gender**.
# - It is successfully plotted.

# %% [markdown]
# ## Plot a pie chart showing the distribution of Activity by day of the week.

# %%
plt.figure(figsize=(10,5))
df['Days'].value_counts().plot(kind='pie',autopct='%1.1f%%',startangle=90)
plt.title('Activity by Day of Week',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observation
# - The Above Dataset, The Day **Wednesday** has Higher than **Other Days**.
# - **Monday** is get **Lower**.

# %% [markdown]
# ## Count the number of entries for each Day of the week.

# %%
df['Days'].value_counts()
# Out:
# Days
# Wednesday    1908
# Tuesday      1870
# Thursday     1723
# Friday       1624
# Saturday     1399
# Sunday       1391
# Monday       1268
# Name: count, dtype: int64

# %% [markdown]
# ## Observation
# - The **Wednesday** has Higher than **Other Days**
# - **Wednesday** got **1908**
# - **Monday** got **1259** it is **Lower** than the **Other days**.

# %% [markdown]
# ## Final Conclusion
# 1. **Sedentary minutes dominate daily activity**, indicating the need for users to engage in more active lifestyles.
# 2. **Steps and Calories burnts** are positively correlated, meaning higher step counts usually lead to higher calories expenditure.
# 3. **Weekends showed more active minutes** suggessting users arre more physically active when free from weekday rountines.
# 4. **Males covered slightly higher average distances than Females**,but the overall gender distribution was almost balanced.
#
# Overall, the dataset provides valuable insights into fitness behaviour and lifestyle patterns. The study higlights the importance of balancing sedentary time with active minutes and shows how activity varies across different demographics and days of the week.
