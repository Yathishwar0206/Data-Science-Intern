# %% [markdown]
# ## Project
# ## Projct name = BMW Data Analysis

# %% [markdown]
# ## Importing liabraries
# - Import numpy as np
# - Import pandas as pd
# - Import matplotlib.pyplot as plt
# - Import seaborn as sns

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the Dataset

# %%
# Update the path below to the correct location of the bmw.csv file in your Google Drive
df = pd.read_csv(r'C:\Users\ADMIN\Desktop\Jupyter folder/Downloads/bmw.csv')
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %% [markdown]
# ## Observation
# - The above dataset is successfully loaded.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %% [markdown]
# ## Handling missing value

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %% [markdown]
# ## Observation
# - The Above dataset there is no missing values were identified.

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %% [markdown]
# ## Visualize the fuel type of the car using bar chart.

# %%
plt.figure(figsize=(10,5))
color = ['red','orange','blue','brown','green']
edgecolor = ['black','red','green','red','lightgreen']
df['fuelType'].value_counts().plot(kind='bar',color=color,edgecolor=edgecolor)
plt.title('Fueltype of the car', fontweight='bold')
plt.xlabel('Fueltype', fontweight='bold')
plt.ylabel('Counts',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observation
# - The above dataset, **Diesel** type car were sold highly.
# - **Electric** vehicle got **Lower**.

# %% [markdown]
# ## Transmission

# %%
gear_type = df.groupby('model')['transmission'].value_counts()
gear_type
# Out:
# model     transmission
# 1 Series  Manual          1103
#           Semi-Auto        505
#           Automatic        361
# 2 Series  Semi-Auto        514
#           Manual           412
#           Automatic        303
# 3 Series  Semi-Auto       1075
#           Automatic        830
#           Manual           538
# 4 Series  Semi-Auto        497
#           Automatic        376
#           Manual           122
# 5 Series  Semi-Auto        519
#           Automatic        501
#           Manual            36
# 6 Series  Automatic         58
#           Semi-Auto         50
# 7 Series  Semi-Auto         66
#           Automatic         40
# 8 Series  Semi-Auto         31
#           Automatic          8
# M2        Semi-Auto         13
#           Automatic          7
#           Manual             1
# M3        Semi-Auto         14
#           Manual             9
#           Automatic          4
# M4        Semi-Auto         90
#           Automatic         30
# ...

# %%
plt.figure(figsize=(10,5))
color = ['red','green','yellow']
gear_type.plot(kind='bar',color=color,edgecolor='black')
plt.title('Gear type of the Car',fontweight='bold')
plt.xlabel('Transmission',fontweight='bold')
plt.ylabel('Count',fontweight='bold')
plt.tight_layout()
for index,value in enumerate(gear_type):
    plt.text(index, value+5, str(value), ha='center', va='bottom', fontweight='bold', fontsize=6)
plt.show()

# %% [markdown]
# ## Observation
# - The Above dataset, **1103** cars sold mostly.In the transmission of **Manual** and the model is **BMW Series 1**.
# - **BMW M2** got **Lower**.

# %% [markdown]
# ## Model vs price

# %%
mp = df.groupby('model')['price'].value_counts()
mp
# Out:
# model     price
# 1 Series  10999    14
#           15000    14
#           8990     13
#           11000    12
#           12000    11
#                    ..
# i8        64980     1
#           67500     1
#           67940     1
#           72000     1
#           74226     1
# Name: count, Length: 6766, dtype: int64

# %%
df['engineSize'].value_counts()
# Out:
# engineSize
# 2.0    6575
# 3.0    2458
# 1.5    1463
# 1.6     109
# 4.4      79
# 0.0      47
# 2.5      14
# 0.6       7
# 2.2       6
# 4.0       6
# 3.2       5
# 1.9       5
# 6.6       2
# 2.8       2
# 1.0       1
# 5.0       1
# 3.5       1
# Name: count, dtype: int64

# %% [markdown]
# ## Observation
# - In **Engine size**, **2.0** size were sold mostly.
# - **1.0, 5.0, 3.5** got **Lower**.

# %% [markdown]
# ## Model and Year

# %%
model_year = df.groupby('year')['model'].apply(list)
for year, model in model_year.items():
    print(f'\n Year : {year}')
    print(f'\n Model : {model}')
# Out:
#  Year : 1996
#
#  Model : [' 5 Series']
#
#  Year : 1997
#
#  Model : [' Z3']
#
#  Year : 1998
#
#  Model : [' Z3']
#
#  Year : 1999
#
#  Model : [' Z3', ' Z3', ' 3 Series', ' Z3']
#
#  Year : 2000
#
#  Model : [' 5 Series', ' 3 Series']
#
#  Year : 2001
#
#  Model : [' 1 Series', ' 3 Series', ' Z3']
#
#  Year : 2002
#
#  Model : [' 5 Series', ' Z3', ' 3 Series', ' 5 Series', ' 3 Series', ' 3 Series']
#
#  Year : 2003
#
#  Model : [' Z4', ' 5 Series']
#
#  Year : 2004
#
#  Model : [' X3', ' 1 Series', ' M3', ' 3 Series', ' M3', ' 3 Series', ' M3', ' M3', ' Z4', ' 3 Series', ' 5 Series', ' Z4']
#
#  Year : 2005
#
#  Model : [' 3 Series', ' 1 Series', ' 6 Series', ' 3 Series', ' M3', ' 3 Series']
#
#  Year : 2006
#
#  Model : [' Z4', ' X3', ' 3 Series', ' X3', ' 3 Series', ' 7 Series', ' 6 Series', ' M6', ' 1 Series', ' 1 Series', ' 3 Series', ' 3 Series', ' 3 Series', ' 5 Series']
#
#  Year : 2007
#
# ...

# %%
model_per_year = df.groupby('year')['model'].count().reset_index()
plt.figure(figsize=(13,9))
plt.bar(model_per_year['year'], model_per_year['model'], color='green')
plt.xlabel('Year',fontweight='bold')
plt.ylabel('Model',fontweight='bold')
plt.title('Number of Model per Year',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observation
# - In the year, **2019** there are sold more **BMW Cars** than other year.

# %% [markdown]
# ## Model and Mileage

# %%
model_mileage = df.groupby('model')['mileage'].count()
print(model_mileage)
# Out:
# model
# 1 Series    1969
# 2 Series    1229
# 3 Series    2443
# 4 Series     995
# 5 Series    1056
# 6 Series     108
# 7 Series     106
# 8 Series      39
# M2            21
# M3            27
# M4           125
# M5            29
# M6             8
# X1           804
# X2           288
# X3           551
# X4           179
# X5           468
# X6           106
# X7            55
# Z3             7
# Z4           108
# i3            43
# i8            17
# Name: mileage, dtype: int64

# %%
plt.figure(figsize=(13,9))
model_mileage.plot(kind='bar',color='skyblue',edgecolor='blue')
plt.title('Mileage of the Car',fontweight='bold')
plt.xlabel('Model of the Car',fontweight='bold')
plt.ylabel('Mileage of the Car',fontweight='bold')
plt.tight_layout()
for i, v in enumerate(model_mileage):
    plt.text(i, v+5, str(v), ha='center', va='bottom', fontweight='bold',fontsize=7)
plt.show()

# %% [markdown]
# ## Observation
# - According to above dataset, **BMW Series 3** has highest mileage than other models. It's got **2443**.
# - **BMW M5** got **Lower**. It is **8** in Mileage.

# %%
df.loc[df['model'].idxmax()]
# Out:
# model                  i8
# year                 2016
# price               48998
# transmission    Automatic
# mileage             10087
# fuelType           Hybrid
# tax                     0
# mpg                 134.5
# engineSize            1.5
# Name: 413, dtype: object

# %% [markdown]
# ## Model vs Year vs Mileage using scatter plot.

# %%
sns.scatterplot(x='model',y='year',hue='mileage',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Observation
# - The most of the **Cars** are **2020** model and it is highest mileage than other model cars.
# - **2012** model car were got **Lower**. The model is **BMW X5**.

# %% [markdown]
# ## Final conclusion.
# According to above dataset,
# 1. **Fuel Type** : Most of the **Car's** fuel types are **Diesel**.
# 2. **Transmission** : The car's transmission types are **Manual** and In this type of Manual **BMW Series 1** were sold higher.
# 3. **Engine Size**  : The most cars **Engine size** are **2.0**.
# 4. **Year**         : In the **year** **2019** model car were sold mostly.
# 5. **Mileage**      : **BMW Series 3** car was the highest given mileage than other model. And the year is **2020**.
