# %%
str="Ajith kumar"
print(str)
len(str)
# Out:
# Ajith kumar
# 11

# %%
print(str[:10])
print(str[:9])
print(str[1:6])
print(str[3:])
print(str[:-5])
print(str[-2:])
print(str[::3])
print(str[::2])
print(str[::6])
print(str[::-2])
# Out:
# Ajith kuma
# Ajith kum
# jith
# th kumar
# Ajith
# ar
# Atka
# Aihkmr
# Ak
# rmkhiA

# %%
print(str[2:3:7])
print(str[-4:-2:8])
print(str[2:-4])
# Out:
# i
# u
# ith k

# %%
str= "Ajay Kumar"
len(str)
# Out:
# 10

# %%
print(str.lower())
print(str.upper())
print(str.count("a")) # Here the Small letter(a) alone counted
print(str.replace("A","Vi")) # Here the name Ajay kumar replaced as Vijay kumar
print(str.replace("Ajay","Ajith")) # Here the name Ajay is replaced as Ajith
# Out:
# ajay kumar
# AJAY KUMAR
# 2
# Vijay Kumar
# Ajith Kumar

# %%
str1="Ajith"
str2="Kumar"
name=str1+' '+str2
print(name)
# Out:
# Ajith Kumar

# %%
print(str1+' '+str2)
# Out:
# Ajith Kumar

# %%
str="Neural"+" "+"Schema"
print(str)
# Out:
# Neural Schema

# %%
a="Ajith"
b="Kumar"
len(a+b)
# Out:
# 10

# %%
str1="Ajith"
str2="Kumar"+" "+"Thala"
num="50"
ak=str1+str2+num
print(ak)
# Out:
# AjithKumar Thala50

# %%
my_string="Warren buffet"
'Warren' in my_string
# Out:
# True

# %%
x="june"
y='2'
date=x+' '+y
print(date,"My birthday")
# Out:
# june 2 My birthday

# %%
text=input("Enter the value:")
revesed_text=text[::-1]
print("Revesed_text:",revesed_text)
# Out:
# Enter the value:Yathishwar
# Revesed_text: rawhsihtaY

# %%
sentence=input("Enter the sentence:")
numb=sentence.replace(" ","")
numb=len(numb)
print("Total character (excluding spaces):",numb)
# Out:
# Enter the sentence:Ajith Kumar
# Total character (excluding spaces): 10

# %%
sentence=input("Enter the value:")
words=sentence.split()
print("GBU",words)
# Out:
# Enter the value:Thalapathy Vijay
# GBU ['Thalapathy', 'Vijay']

# %%
my_list=["02022005"]
print(my_list)
print(type(my_list))
# Out:
# ['02022005']
# <class 'list'>

# %%
primary=['Vijay','Ajith','Suriya','Karthik','Soori']
print(primary[1:4])
print(primary[:4])
print(primary[3:])
print(primary[::4])
print(primary[-2::])
print(primary[::-3])
# Out:
# []
# ['Vijay,Ajith,Suriya,Karthik,Soori']
# []
# ['Vijay,Ajith,Suriya,Karthik,Soori']
# ['Vijay,Ajith,Suriya,Karthik,Soori']
# ['Vijay,Ajith,Suriya,Karthik,Soori']

# %%
my_list=['Hello world']
my_list
print(type(my_list))
len(my_list)
# Out:
# <class 'list'>
# 1

# %%
my_line=['String','200','100.365','o','True']
my_line
print(type(my_line))
# Out:
# <class 'list'>

# %%
#min
y=[1,2,3,4]
print(min(y))
# Out:
# 1

# %%
#max
my_list=[1,2,3,4]
print(max(my_list))
# Out:
# 4

# %%
my_list=[1,2,3,4]
print(sum(my_list))
# Out:
# 10

# %%
numb=[64,78,99,45,100]
print(sorted(numb))
# Out:
# [45, 64, 78, 99, 100]

# %%
new_list=[69,60,88,72,100]
print(sorted(new_list,reverse=True))
# Out:
# [100, 88, 72, 69, 60]

# %%
#List method
y=[10,20,30,100]
y.append('yathish')
print(y)
# Out:
# [10, 20, 30, 100, 'yathish']

# %%
y=[10,20,30,100]
y.extend(['20','30','40','100'])
print(y)
# Out:
# [10, 20, 30, 100, '20', '30', '40', '100']

# %%
y=[10, 20, 30, 100, 'yathish']
y.extend(['the python developer'])
print(y)
# Out:
# [10, 20, 30, 100, 'yathish', 'the python developer']

# %%
my_list=[1*2*3*4-2/2]
print(sum(my_list))
# Out:
# 23.0

# %%
y=[10,20,30,100,'vijay','Ajith','Suriya','Karthik']
y.pop(7) # pop
# Out:
# 'Karthik'

# %%
y=[10,20,30,100,'vijay','Ajith','Suriya']
y.remove('Suriya')
print(y)
# Out:
# [10, 20, 30, 100, 'vijay', 'Ajith']

# %%
y=[10,20,30,100,'vijay','Ajith','Suriya','Ajith','vijay','Ajay']
y.count('vijay')
# Out:
# 2

# %%
y=[10,20,30,100,'vijay','Ajith','Suriya','Ajith']
y.index(30)
# Out:
# 2

# %%
y=[10,20,30,50,90,70,64,100]
y.sort()
print(y)
# Out:
# [10, 20, 30, 50, 64, 70, 90, 100]

# %%
y=[10,20,30,50,90,70,64,100]
y.sort(reverse=True)
print(y)
# Out:
# [100, 90, 70, 64, 50, 30, 20, 10]

# %%
list1=[1,2,3]
list2=['a,b,c']
list3=[4,5,6]
my_lists=(list1,list2,list3)
print(my_lists)
# Out:
# ([1, 2, 3], ['a,b,c'], [4, 5, 6])

# %%
my_lists[2]
# Out:
# [4, 5, 6]

# %%
my_lists[0][1]
# Out:
# 2

# %%
# Basic list question
fruits=['apple','banana','graps','jackfruit','mango','pappaya']
print("Enter the Fruits:",fruits)
# Out:
# Enter the Fruits: ['apple', 'banana', 'graps', 'jackfruit', 'mango', 'pappaya']

# %%
number=[1,3,5,7,9,11]
print("First number:",number[2])
print("Last number:",number[-1])
# Out:
# First number: 5
# Last number: 11

# %%
fruits=['apple','banana','graps','jackfruit','mango','pappaya']
number=[1,3,5,7,9,11]
fruits.extend(number)
print(fruits)
# Out:
# ['apple', 'banana', 'graps', 'jackfruit', 'mango', 'pappaya', 1, 3, 5, 7, 9, 11]

# %%
x=['apple','banana','graps','jackfruit','mango','pappaya', 1, 3, 5, 7, 9,]
x[0]=("Black")
print(x)
# Out:
# ['Black', 'banana', 'graps', 'jackfruit', 'mango', 'pappaya', 1, 3, 5, 7, 9]

# %%
x=['apple','banana','graps','jackfruit','mango','pappaya', 1, 3, 5, 7, 9,]
x.insert(2,"orange")
print(x)
# Out:
# ['apple', 'banana', 'orange', 'graps', 'jackfruit', 'mango', 'pappaya', 1, 3, 5, 7, 9]

# %%
# Tuple(index,slicing)
v=(1,2,3,4,5,'yathish',2.6,True)
print(type(v))
print(v[2])
print(v[2:5]) # slicing
print(v[::-1])
print(v[7::-1])
len(v)
# Out:
# <class 'tuple'>
# 3
# (3, 4, 5)
# (True, 2.6, 'yathish', 5, 4, 3, 2, 1)
# (True, 2.6, 'yathish', 5, 4, 3, 2, 1)
# 8

# %%
#
