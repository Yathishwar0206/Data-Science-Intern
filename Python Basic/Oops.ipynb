# %%
# Oops method for Car.
class Car:
  def __init__(self,brand,model,year):
    self.brand= brand
    self.model=model
    self.year=year
car1=Car('Audi','A4',2022)
car2=Car('BMW','X5',2021)
print(car1.brand)
print(car1.model)
print(car1.year)
print(car2.brand)
print(car2.model)
print(car2.year)
# Out:
# Audi
# A4
# 2022
# BMW
# X5
# 2021

# %%
# Oops method for Bike.
class Bike:
    def __init__(self,brand,model,year):
        self.brand=brand
        self.model=model
        self.year=year
bike1=Bike('Royal Enfield','Classic 350',2020)
bike2=Bike('Yamaha','Rx100',2021)
print(bike1.brand,bike1.model,bike1.year)
print(bike2.brand,bike2.model,bike2.year)
# Out:
# Royal Enfield Classic 350 2020
# Yamaha Rx100 2021

# %%
class Animal:
  def speaks(self):
    #self.speaks
    print('Animal speaks')

class Dog(Animal):
  def barks(self):
    #self.barks
    print('Dog barks')

c=Animal()
d=Dog()
c.speaks()
d.barks()
# Out:
# Animal speaks
# Dog barks

# %%
# Inheritance for bird.
class Bird:
  def strength(self):
    #self.strength
    print('Birds Strenght')
# Eagle
class Eagle(Bird):
  def Positivity(self):
    #self.Positivity
    print('King of the Sky')

c=Bird()
c=Eagle()
f.strength()
f.Positivity()
#c.Positivity()
f.strength()
# Out:
# Birds Strenght
# King of the Sky
# Birds Strenght

# %%
class Bird: # Parent
  def strenght(self):
    print('Bird Strenght')
# Peacock
class Peacock(Bird): # child
  def Beautifull(self):
    print('Peacock is Beautiful')

a = Bird()
a = Peacock()
b.strenght()
b.Beautifull()
# Out:
# Bird Strenght
# Peacock is Beautiful

# %%
class Bird: # Parental method
  def strenght(self):
    print('Bird Strenght')
  def Country(self):
    print('National Bird')
# Peacock
class Peacock(Bird): # child method
  def Beautifull(self):
    print('Peacock is Beautiful')
  def India(self):
    print('Peacock is National bird of India')

a = Bird()
a = Peacock()
b.strenght()
b.Beautifull()
c.Country()
c.India()
# Out:
# Bird Strenght
# Peacock is Beautiful
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1249801961.py in <cell line: 0>()
#      15 b.strenght()
#      16 b.Beautifull()
# ---> 17 c.Country()
#      18 c.India()
#
# AttributeError: 'Eagle' object has no attribute 'Country'

# %%
# Roaster
class Roaster: # Parental method
  def relative(self):
    print('Roaster is Father')
# Chicken
class Chicken(Roaster): # child method
  def child(self):
    print('Chicken is Son')
x=Roaster()
y=Chicken()
x.relative()
y.child()
# Out:
# Roaster is Father
# Chicken is Son

# %%
# Animal
class Animal: # Parental method
  def speak(self):
    print('Animal speaks')
# Lion barks
class Lion(Animal): # Child method
  def barks(self):
    print('Lion barks')
# Cup
class Cup(Lion):
  def barks(self):
    print('Cup barks')

x=Animal()
y=Lion()
z=Cup()
x.speak()
y.barks()
z.barks()
# Out:
# Animal speaks
# Lion barks
# Cup barks

# %%
# Multiple level
class Father:
  def skills(self):
    print("Father's Skills")
class Mother:
  def skills(self):
    print("Mother's Skills")
class child(Father,Mother):
  def skills(self):
    print('The child have their parents skills')

x=Father()
y=Mother()
z=child()
x.skills()
y.skills()
z.skills()
# Out:
# Father's Skills
# Mother's Skills
# The child have their parents skills

# %%
# Multiple
class Grandfather:
  def behaviour(self):
    print("Grandfather's Behaviour")
class Father:
  def behaviour(self):
    print("Father's Behaviour")
class Mother:
  def behaviour(self):
    print("Mother's Behaviour")
class child(Grandfather,Father,Mother):
  def behaviour(self):
    print('The child having the behaviour like their preceded generation')

x=Grandfather()
y=Father()
z=Mother()
a=child()
x.behaviour()
y.behaviour()
z.behaviour()
a.behaviour()
# Out:
# Grandfather's Behaviour
# Father's Behaviour
# Mother's Behaviour
# The child having the behaviour like their preceded generation
