# %%
# Print numbers from 1 to 5.
x = 0
while x < :
  print('x currently is : ',x)
  x = x + 1
# Out:
# x currently is :  0
# x currently is :  1
# x currently is :  2
# x currently is :  3
# x currently is :  4
# x currently is :  5

# %%
# Print "Hello" 5 times
x = 0
while x < 5:
  print('Hello')
  x = x + 1
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
# Print even numbers from 2 to 10
x = 2
while x < 10:
  print('Even number : ',x)
  x = x + 2
# Out:
# Even number :  2
# Even number :  4
# Even number :  6
# Even number :  8

# %%
# Countdown from 5 to 1.
x = 5
while x
