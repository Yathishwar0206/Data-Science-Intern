# %%
# Tuple index
my_tuple=(5,7,9,11,13,15)
my_tuple[2]
# Out:
# 9

# %%
len(my_tuple)
# Out:
# 6

# %%
my_tuple[5]
# Out:
# 15

# %%
# Tuple.count
mt=(1,2,3,6,7,2,4,9,5,1,0,5,6)
len(mt)
# Out:
# 13

# %%
print(mt.count(1))
print(mt.count(2))
print(mt.count(4))
print(mt.count(5))
print(mt.count(6))
print(mt.count(3))
# Out:
# 2
# 2
# 1
# 2
# 2
# 1

# %%
# Tuple is immutablility
mt[0]
# Out:
# 1

# %%
mt[0]="Strike"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-15-1960017068.py in <cell line: 0>()
# ----> 1 mt[0]="Strike"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Tuple will not access the append, extend, remove, pop
mt.append("yathish")
mt.remove(4)
mt.extend([1,2,3])
mt.pop(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-18-1395546064.py in <cell line: 0>()
#       1 # Tuple will not access the append, extend, remove, pop
# ----> 2 mt.append("yathish")
#       3 mt.remove(4)
#       4 mt.extend([1,2,3])
#       5 mt.pop(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# Set
mt=set()
print(mt)
# Out:
# set()

# %%
# while doing the set use {}
mt={1,3,6,7,2,5}
print(mt)
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
mt={(1,2,3,5,7,10)} # here we can Insert the tuplle in the set
print(mt)
# Out:
# {(1, 2, 3, 5, 7, 10)}

# %%
mt1={[1,2,3,5,7,10]} # Here we can't Insert the list in the set.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-27-3160233661.py in <cell line: 0>()
# ----> 1 mt1={[1,2,3,5,7,10]}
#
# TypeError: unhashable type: 'list'

# %%
# add
Ms={1,5,7,9,3,2,0,}
Ms.add('a')
print(Ms)
# Out:
# {0, 1, 2, 3, 'a', 5, 7, 9}

# %%
Ms.add('b')
print(Ms)
# Out:
# {0, 1, 2, 3, 5, 7, 9, 'a', 'b'}

# %%
# Update here we can this method for multiple elements ([ ]).
Ms.update([10,11,15,28,30])
print(Ms)
# Out:
# {0, 1, 2, 3, 5, 7, 9, 10, 11, 15, 'a', 'b', 28, 30}

# %%
#  Remove
Ms={0, 1, 2, 3, 5, 7, 9, 10, 11, 15, 'a', 'b', 28, 30}
Ms.remove('b')
print(Ms)
# Out:
# {0, 1, 2, 3, 5, 7, 9, 10, 11, 15, 'a', 28, 30}

# %%
Ms.remove(0)
print(Ms)
# Out:
# {1, 2, 3, 5, 7, 9, 10, 11, 15, 'a', 28, 30}

# %%
# Union We can use this code  (A.union(b)) and A|B
A={1,2,3,4,5,6}
B={4,5,6,7,9,10}
A|B
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9, 10}

# %%
# Intersection We can use this code (A.intersection(b)) and A&B
A&B
# Out:
# {4, 5, 6}

# %%
# Difference Here we can use this code also (A-B)
A.difference(B)
# Out:
# {1, 2, 3}

# %%
B.difference(A)
# Out:
# {7, 9, 10}

# %%
# Symmetric_difference
A^B
# Out:
# {1, 2, 3, 7, 9, 10}

# %%
X={10,20,30,40,50,60}
Y={40,50,60,70,100}
X.union(Y)
# Out:
# {10, 20, 30, 40, 50, 60, 70, 100}

# %%
X&Y
# Out:
# {40, 50, 60}

# %%
X.difference(Y)
# Out:
# {10, 20, 30}

# %%
Y.difference(X)
# Out:
# {70, 100}

# %%
X^Y
# Out:
# {10, 20, 30, 70, 100}

# %%
# Dictonaries
a={'Name': 'Yathishwar','Skills': 'Python, Machine learning, Deep learning','Promotion':'2025,2027,2029','Position':'General Manager'}
a['Name']
# Out:
# 'Yathishwar'

# %%
# keys
a.keys()
# Out:
# dict_keys(['Name', 'Skills', 'Promotion', 'Position'])

# %%
# Value
a.values()
# Out:
# dict_values(['Yathishwar', 'Python, Machine learning, Deep learning', '2025,2027,2029', 'General Manager'])

# %%
# Items
a.items()
# Out:
# dict_items([('Name', 'Yathishwar'), ('Skills', 'Python, Machine learning, Deep learning'), ('Promotion', '2025,2027,2029'), ('Position', 'General Manager')])

# %%
a.get('Position')
# Out:
# 'General Manager'

# %%
# index
a={'Name': 'Yathishwar','Skills': ['Python', 'Machine learning', 'Deep learning'],'Promotion':[2025,2027,2029],'Position':'General Manager'}
a['Skills'][2]
# Out:
# 'Deep learning'

# %%
a['Promotion'][1]
# Out:
# 2027

# %%
# Upper
a['Skills'][0].upper()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-10-1144956884.py in <cell line: 0>()
#       1 # Upper
# ----> 2 a['Skills'][0].upper()
#
# NameError: name 'a' is not defined

# %%
# Update
a.update({'Experience':'5 years'})
a
# Out:
# {'Name': 'Yathishwar',
#  'Skills': ['Python', 'Machine learning', 'Deep learning'],
#  'Promotion': [2025, 2027, 2029],
#  'Position': 'General Manager',
#  'Experience': '5 years'}

# %%
# Dict
Country_list=['India','Srilanks','America','Europe']
City_list=['New Delhi','Colombo','Washington','London']

# %%
# Zip
y=zip(Country_list,City_list)

# %%
# dict
country_city_dict = dict(y)
print(country_city_dict)
# Out:
# {'India': 'New Delhi', 'Srilanks': 'Colombo', 'America': 'Washington', 'Europe': 'London'}

# %%
a={'Name': 'Yathishwar','Skills': ['Python', 'Machine learning', 'Deep learning'],'Promotion':[2025,2027,2029],'Position':'General Manager'}
['Skills'][0].upper()
# Out:
# 'a'

# %%
a.get('Position')
# Out:
# 'General Manager'

# %%
employee_dict={'Skills': ['Python', 'Machine learning', 'Deep learning']}
employee_dict['Skills'][0].upper()
# Out:
# 'PYTHON'
