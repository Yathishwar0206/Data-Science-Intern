# %%
# Conditional Statement
age=int(input('Enter the age:'))
if age>=18:
  print('Eligible for vote')
else:
  print('Not eligilble for vote')
# Out:
# Enter the age:27
# Eligible for vote

# %%
numb=6
if numb % 2 == 0:
  print('The number is even')
else:
  print('The number is odd')
# Out:
# The number is even

# %%
numb=int(input('Enter the numeber:'))
if numb % 2 == 0:
  print('The number is even')
else:
  print('The number is odd')
# Out:
# Enter the numeber:7
# The number is odd

# %%
Height=int(input('Enter the height:'))
if Height>=170:
  print('Eligible for Indian Army')
else:
  print('Not eligible for Indian Army')
# Out:
# Enter the height:173
# Eligible for Indian Army

# %%
# If,elif,else
Weather=input('Weather:')
if Weather=='sunny':
  print('Go for walk')
elif Weather=='Rainy':
  print('Take an umberlla')
else:
  print('Stay indoor')
# Out:
# Weather:Rainy
# Take an umberlla

# %%
# Here the 'elif' has come multiple times.
Marks=int(input('Enter the mark:'))
if Marks>=90:
  print('Grade O')
elif Marks>=80:
  print('Grade A+')
elif Marks>=70:
  print('Grade A')
elif Marks>=60:
  print('Grade B+')
elif Marks>=50:
  print('Grade B')
elif Marks>=40:
  print('Grade C')
else:
  print('Fail')
# Out:
# Enter the mark:95
# Grade O

# %%
point=float(input('Enter the point:'))
if point>=7.5:
  print('Distinction')
elif point>=6:
  print('First Class')
elif point>=5:
  print('Second Class')
elif point>=4:
  print('Third Class')
elif point>=3:
  print('Pass Class')
# Out:
# Enter the point:8.1
# Distinction

# %%
numb=int(input('Enter the number:'))
if numb>0:
  print('The number is positive')
elif numb<0:
  print('The number is negative')
else:
  print('The number is zero')
# Out:
# Enter the number:6
# The number is positive

# %%
# Here the number 5 is given for common number.
numb=int(input('Enter the number:'))
if numb>5:
  print('The number is positive')
elif numb<5:
  print('The number is negative')
else:
  print('The number is Equal')
# Out:
# Enter the number:6
# The number is positive

# %%
a = input('Name:')
if a == 'Duraisingam':
  print('He is a police officer')
else:
  print('He is a Army officer')
# Out:
# Name:Suriya
# He is a Army officer

# %%
a=input('Enter the statement:')
if a==('Meghna died'):
  print('Suriya meets priya')
else:
  print('Suriya meets meghna')
# Out:
# Enter the statement:Meghna died
# Suriya meets priya

# %%
# Checking the Age and Citizenship
age=18
citizen='Yes'
if age>=18:
  if citizen=='Yes':
    print('Eligible to put vote')
  else: # Removed condition after else
    print('Not eliglible to put vote') # This print statement is for age >= 18 but citizen is not 'Yes'
else: # Removed condition after else
    print('Not eliglible to put vote') # This print statement is for age < 18
# Out:
# Eligible to put vote

# %%
# Login
username=input('Enter the username:')
password=int(input('Enter the password:'))
if username=='yathish@+':
  if password==9876:
    print('Login get successful')
  else:
    print('password is incorrect')
else:
  print('username is incorrect')
# Out:
# Enter the username:yathish@+
# Enter the password:9876
# Login get successful

# %%
numb=int(input('Enter the number:'))
if numb%2==0 and numb>=0:
  print('The number is even and it is positive')
else:
  print('The number is odd and it is negative')
# Out:
# Enter the number:5
# The number is odd and it is negative

# %%
# Login
correct_username='yathish'
correct_password=1234
username=input('Enter Username: ')
password=int(input('Enter password: '))
if username==correct_username and password==correct_password:
  print('Login successful')
else:
  print('Login failed')
# Out:
# Enter Username: yathish
# Enter password: 1234
# Login successful

# %%
correct_username='yathish@+'
correct_password=262005
username=input('Enter the username:')
password=int(input('Enter the password:'))
if username == correct_username:
  if password == correct_password:
    print('Login successful')
  else:
    print('Invalid password')
else:
  print('Invalid username')
# Out:
# Enter the username:yathish@+
# Enter the password:252005
# Invalid password

# %%
age=int(input('Enter the age:'))
citizen=input('Yes/No':)
if age >=18 and citizen =='Yes':
