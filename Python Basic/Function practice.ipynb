# %%
# Function
# Print numbers from 1 to 5.
def print_numbers():
  for i in range(1, 6):
    print(i)

# Original logic modified to correctly count numbers in an iterable
def count_numbers(numbers):
  result = 0
  for number in numbers:
    result += 1
  return result
